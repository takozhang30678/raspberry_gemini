# %%
import sys
import platform

# 1. 檢查目前使用的 Python 位置與版本
print(f"目前核心路徑: {sys.executable}")
print(f"Python 版本: {platform.python_version()}")
print(sys.executable)

# 2. 測試繪圖功能 (驗證 Jupyter 介面是否正常)
import matplotlib.pyplot as plt
import numpy as np
print(sys.executable)

x = np.linspace(0, 10, 100)
y = np.sin(x)

plt.figure(figsize=(8, 4))
plt.plot(x, y, label='Sine Wave', color='blue')
plt.title("Jupyter Environment Test Success!")
plt.legend()
plt.show()
# Out:
# 目前核心路徑: /home/pi/Documents/.venv/bin/python
# Python 版本: 3.13.5
# /home/pi/Documents/.venv/bin/python
# /home/pi/Documents/.venv/bin/python
